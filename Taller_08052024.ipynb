# %% [markdown]
# <a href="https://colab.research.google.com/github/vgonzalezg0/TrabajoFinal_Ejemplo/blob/main/Taller_08052024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #<font color='46B8A9'> **TALLER TRABAJO FINAL** </font>

# %% [markdown]
# ##**1. Pandas**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# En Computación y Ciencia de datos, pandas es una biblioteca de software escrita como extensión de NumPy para manipulación y análisis de datos para el lenguaje de programación Python. En particular, ofrece estructuras de datos y operaciones para manipular tablas numéricas y series temporales.

# %%
import pandas as pd

# %% [markdown]
# ### **Series**
# Es una matriz unidimensional que contiene datos de cualquier tipo.

# %%
numeros = ['e', 2, 3]
miserie = pd.Series(numeros)
print(miserie)
# Out:
# 0    e
# 1    2
# 2    3
# dtype: object

# %%
miserie[0] # Indexación
# Out:
# 'e'

# %%
miserie = pd.Series(numeros, index = ["x", "y", "z"]) # Crear etiquetas
miserie
# Out:
# x    e
# y    2
# z    3
# dtype: object

# %%
calorias = {"Dia1": 420, "Dia2": 380, "Dia3": 390}
miserie = pd.Series(calorias)
miserie
# Out:
# Dia1    420
# Dia2    380
# Dia3    390
# dtype: int64

# %% [markdown]
# ###**Dataframes**
#
# Son paneles bidimensionales compuestos por filas y columnas.

# %%
data = {
  "calorias": [420, 380, 390],
  "duracion": [50, 40, 45]
}
df = pd.DataFrame(data)
df.head()
# Out:
#    calorias  duracion
# 0       420        50
# 1       380        40
# 2       390        45

# %%
print(df.loc[0])
# Out:
# calorias    420
# duracion     50
# Name: 0, dtype: int64

# %%
print(df.loc[[0, 2]])
# Out:
#    calorias  duracion
# 0       420        50
# 2       390        45

# %% [markdown]
# #### **Cargar archivos en un DataFrame**

# %% [markdown]
# ###### **CSV**

# %%
apellidos = pd.read_csv('https://raw.githubusercontent.com/valeriag1/TrabajoFinal_Prueba/main/Datasets/ApellidosArgentina.csv')
apellidos.head()
# Out:
#     lastname    cant  provincia_id provincia_nombre
# 0   Gonzalez  315472             6     Buenos Aires
# 1  Rodriguez  242834             6     Buenos Aires
# 2      Gomez  223400             6     Buenos Aires
# 3  Fernandez  209765             6     Buenos Aires
# 4      Lopez  200199             6     Buenos Aires

# %%
type(apellidos)
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_csv('/content/sample_data/california_housing_test.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ###### **XLSX**

# %%
IPM = pd.read_excel(r'https://github.com/danialk20/Analitica/raw/765e1cb59ab28c8d50538ca39c11c6834d163104/ConjuntoDatos_base/Pobreza%20multidimensional.xlsx')
IPM.head(3)
# Out:
#    Código Departamento Departamento  Código Entidad    Entidad Dimensión  \
# 0                    1     Colombia            1001   Colombia   Pobreza
# 1                    1     Colombia            1001   Colombia   Pobreza
# 2                    5    Antioquia            5000  Antioquia   Pobreza
#
#              Subcategoría                                 Indicador  \
# 0  Indicadores de pobreza  Índice de pobreza multidimensional - IPM
# 1  Indicadores de pobreza  Índice de pobreza multidimensional - IPM
# 2  Indicadores de pobreza  Índice de pobreza multidimensional - IPM
#
#   Dato Numérico  Dato Cualitativo   Año  Mes Fuente  \
# 0         48,97               NaN  2005   12   DANE
# 1         25,62               NaN  2018   12   DANE
# 2         44,29               NaN  2005   12   DANE
#
#                                   Unidad de Medida
# 0  Porcentaje (el valor está multiplicado por 100)
# 1  Porcentaje (el valor está multiplicado por 100)
# ...

# %% [markdown]
# #### **Revisión de datos**
# Pandas ofrece diversas funciones para explorar los datos contenidos en un dataframe.
#
# | Función            | Descripción                                                                         |
# |--------------------|-------------------------------------------------------------------------------------|
# | `df.head(n)`       | Devuelve las primeras n filas del DataFrame                                         |
# | `df.tail(n)`       | Devuelve las últimas n filas del DataFrame                                          |
# | `df.info()`        | Proporciona un resumen del DataFrame, incluyendo los tipos de datos y el uso de memoria |
# | `df.describe()`    | Proporciona estadísticas resumidas para las columnas numéricas en el DataFrame      |
# | `df.shape`         | Devuelve una tupla que representa las dimensiones del DataFrame (filas, columnas)   |
# | `df.columns`       | Devuelve una lista de los nombres de las columnas en el DataFrame                    |
# | `df.index`         | Devuelve el índice (etiquetas de fila) del DataFrame                                 |
# | `df.dtypes`        | Devuelve los tipos de datos de cada columna en el DataFrame                          |

# %% [markdown]
# ####**Funciones**
# | Método | Descripción |
# | --- | --- |
# | `df['columna'].astype(dtype)` | Convierte la columna a un tipo de dato específico |
# | `df['columna'].mean()` | Devuelve la media de los valores de la columna |
# | `df['columna'].median()` | Devuelve la mediana de los valores de la columna |
# | `df['columna'].min()` | Devuelve el valor mínimo de la columna |
# | `df['columna'].max()` | Devuelve el valor máximo de la columna |
# | `df['columna'].sum()` | Devuelve la suma de los valores de la columna |
# | `df['columna'].count()` | Devuelve el número de valores no nulos de la columna |
# | `df['columna'].value_counts()` | Devuelve una serie con el número de apariciones de cada valor único en la columna |
# | `df['columna'].unique()` | Devuelve un array con los valores únicos de la columna |
# | `df['columna'].nunique()` | Devuelve el número de valores únicos en la columna |
# | `df['columna'].apply(func)` | Aplica una función personalizada a cada elemento de la columna |
# | `df['columna'].replace(old, new)` | Reemplaza valores específicos en la columna |
#
#
# Puede consultar más en este [enlace](https://pandas.pydata.org/pandas-docs/stable/reference/frame.html)

# %% [markdown]
# #### **Selección de filas**
# | Método | Descripción |
# |--------|-------------|
# | `loc[]` | Selecciona filas por etiquetas o valores de índice |
# | `iloc[]` | Selecciona filas por posición de índice |

# %%
df.iloc[2:5]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df.loc[2:5]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
#
#    population  households  median_income  median_house_value
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0
# 5       663.0       204.0         1.6635             67000.0

# %% [markdown]
# #### **Selección columnas**

# %%
coordenadas = df[["longitude", "latitude"]]
coordenadas.head()
# Out:
#    longitude  latitude
# 0    -122.05     37.37
# 1    -118.30     34.26
# 2    -117.81     33.78
# 3    -118.36     33.82
# 4    -119.67     36.33

# %%
coordenadas = df.iloc[20:25, :2]
coordenadas
# Out:
#     longitude  latitude
# 20    -122.15     37.75
# 21    -121.37     38.68
# 22    -118.16     34.07
# 23    -122.20     37.79
# 24    -117.28     33.28

# %%
columas_interes = df.loc[:, "housing_median_age":"population"]
columas_interes.head()
# Out:
#    housing_median_age  total_rooms  total_bedrooms  population
# 0                27.0       3885.0           661.0      1537.0
# 1                43.0       1510.0           310.0       809.0
# 2                27.0       3589.0           507.0      1484.0
# 3                28.0         67.0            15.0        49.0
# 4                19.0       1241.0           244.0       850.0

# %% [markdown]
# [Documentación Pandas](https://pandas.pydata.org/docs/user_guide/index.html)

# %% [markdown]
# ####**Recorrer dataframe**

# %%
casas_antiguas = pd.DataFrame(columns=df.columns)

for indice_fila, fila in df.iterrows():
    for columna in df.columns:
        if columna == 'housing_median_age':
            valor_celda = fila[columna]
            if valor_celda > 50:
                casas_antiguas = pd.concat([casas_antiguas, pd.DataFrame([fila])])
f'Hay {len(casas_antiguas)} unidades de vivienda antiguas'
##Preguntar el fin de recorrer
# Out:
# 'Hay 184 unidades de vivienda antiguas'

# %% [markdown]
# ##**2. Fechas**

# %%
from datetime import datetime
import pytz
import time

# %%
fecha = datetime.now().strftime('%Y-%m-%d') #UTC (Tiempo Universal Coordinado)
fecha
# Out:
# '2024-05-08'

# %%
zona_colombia = pytz.timezone('America/Bogota')
time_stamp = datetime.now(zona_colombia).strftime('%Y-%m-%d') # %H:%M:%S.%f
time_stamp
# Out:
# '2024-05-08'

# %% [markdown]
# ##**3. Manipulación de archivos**

# %%
import os

# %%
CarpetaNueva = 'CarpetaFinal'
os.makedirs(CarpetaNueva, exist_ok=True)

# %%
ruta_carpeta = '/content/CarpetaFinal'

# %%
ruta_archivocsv = os.path.join(ruta_carpeta, 'datos.csv')
casas_antiguas.to_csv(ruta_archivocsv, index=False)
ruta_archivoxlsx = os.path.join(ruta_carpeta, 'datos.xlsx')
casas_antiguas.to_excel(ruta_archivoxlsx, index=False)

# %%
# #ADICIONAL
# from google.colab import drive
# drive.mount('/content/drive')
# import os

# drive_path = '/content/drive/'
# file_path = 'path_to_your_file_in_drive'
# full_path = os.path.join(drive_path, file_path)
